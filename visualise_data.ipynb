# %%
import os, requests
import numpy as np

# %load_ext autoreload
# %autoreload 2

from summarise_dataset import *
from filter import *

# %%
fname = []
for j in range(3):
  fname.append('steinmetz_part%d.npz'%j)

alldat = np.array([])
for j in range(len(fname)):
  alldat = np.hstack((alldat, np.load('steinmetz_part%d.npz'%j, allow_pickle=True)['dat']))

# %%
sessionID = 10
session = alldat[sessionID]

# %%
summarise_session(alldat, sessionID, select_areas=None, unfair_only=True,chosey_only=True,nonzero_only=True)
# Out:
# Session ID: 10
#
# CP: 275 neurons
# LSc: 72 neurons
# LSr: 4 neurons
# MOp: 447 neurons
# PT: 45 neurons
# root: 14 neurons
#
# 342 trials total
# right (-1): 119 (34%)
# centre (0): 97 (28%)
# left (1)  : 126 (36%)
#
# 24 non-zero contrast unfair trials with a choice
# right (-1): 14 (58%)
# centre (0): 0 (0%)
# left (1)  : 10 (41%)

# %%
plot_session(alldat, sessionID, select_areas=None, unfair_only=True,chosey_only=True,nonzero_only=True)

# %%
interesting_areas = ['MOp','VISp']
interesting_sessions = []
for i, sess in enumerate(alldat):
    for ba in sess['brain_area']:
        if ba in interesting_areas and i not in interesting_sessions:
            interesting_sessions.append(i)

for i in interesting_sessions:
    plot_session(alldat, i,select_areas = interesting_areas, unfair_only=True,chosey_only=True,nonzero_only=True)
